# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()
G.add_edge(1,2)
G.add_edge(1,3)
G.add_edge(2,3)
nx.draw(G, with_labels=True)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

for i in range(0,n_pop):
    G.add_edge(pop[i][1],pop[i][2])


#nx.draw(G, with_labels=True)
pos = nx.spring_layout(G) 
nx.draw(G,pos)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

for i in range(0,n_pop):
    G.add_edge(old_pop[i][1],old_pop[i][2])


fig = plt.figure(figsize=(40, 40)) 
#G = nx.fast_gnp_random_graph(300, 0.02, seed=1337) 
nx.draw(G, node_size=30,with_labels=True,font_color="r") 
plt.axis('equal') 
plt.show() 
fig.savefig('test.svg')

# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

for i in range(0,n_pop):
    G.add_edge(pop[i][1],pop[i][2])

fig = plt.figure(figsize=(40, 40)) 
#G = nx.fast_gnp_random_graph(300, 0.02, seed=1337) 
nx.draw(G, node_size=30,with_labels=True,font_color="r") 
plt.axis('equal') 
plt.show() 
fig.savefig('test2.svg')
