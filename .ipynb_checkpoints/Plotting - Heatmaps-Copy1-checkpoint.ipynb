# %%
import numpy as np
import matplotlib.pyplot as plt


import pandas as pd
import glob

import matplotlib.patches as mpatches
import matplotlib.colors as colors

# %%
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
        'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
        cmap(np.linspace(minval, maxval, n)))
    return new_cmap

# %%
random_txt_files = np.array(glob.glob('../data/RandomTesting/*.txt'))
# targetted_txt_files = np.array(glob.glob('../data/TargettedTesting/*.txt'))

print(len(random_txt_files))
print(random_txt_files)
# print(targetted_txt_files)
# Out:
# 10053
# ['../data/RandomTesting/Random_Testing_5_RAT_0.75_0.1_PCR_1.0_0.9_201003074301175272.txt'
#  '../data/RandomTesting/Random_Testing_5_RAT_0.75_0.8_PCR_1.0_0.2_201003133143499790.txt'
#  '../data/RandomTesting/Random_Testing_1_RAT_0.7_0.2_PCR_1.0_0.8_201003062600395058.txt'
#  ...
#  '../data/RandomTesting/Random_Testing_1_RAT_0.85_1.0_PCR_1.0_0.0_201003054825755014.txt'
#  '../data/RandomTesting/Random_Testing_1_RAT_0.9_0.7_PCR_1.0_0.3_201003104112731097.txt'
#  '../data/RandomTesting/Random_Testing_5_RAT_0.7_0.7_PCR_1.0_0.3_201003144152873804.txt']

# %%
def split_sensitivity(files, choice):
    # split by sensitivities

    point7 = []
    point75 = []
    point8 = []
    point85 = []
    point9 = []
    point95 = []
    point10= []
    
    for i in range(0,len(files)):
        if(files[i].split("_")[4] == "0.7"):
            point7.append(files[i])
        elif(files[i].split("_")[4] == "0.75"):
            point75.append(files[i])
        elif(files[i].split("_")[4] == "0.8"):
            point8.append(files[i])
        elif(files[i].split("_")[4] == "0.85"):
            point85.append(files[i])
        elif(files[i].split("_")[4] == "0.9"):
            point9.append(files[i])
        elif(files[i].split("_")[4] == "0.95"):
            point95.append(files[i])
        elif(files[i].split("_")[4] == "1.0"):
            point10.append(files[i])
        
#### Now all files are split into these different sensitivities.
    
    if(choice == 0.7):
        return np.array(point7)
    elif(choice == 0.75):
        return np.array(point75)
    elif(choice == 0.8):
        return np.array(point8)
    elif(choice == 0.85):
        return np.array(point85)
    elif(choice == 0.9):
        return np.array(point9)
    elif(choice == 0.95):
        return np.array(point95)
    elif(choice == 10.0):
        return np.array(point10)
    else:
        print("Invalid choice")

# %%
def split_test_rate(files, choice):
    # split by test-rates

    zero = []
    one  = []
    two  = []
    four = []
    five = []
    six  = []
    eight= []
    ten  = []
    
    for i in range(0,len(files)):
        if(files[i].split("_")[2] == "0"):
            zero.append(files[i])
        elif(files[i].split("_")[2] == "1"):
            one.append(files[i])
        elif(files[i].split("_")[2] == "2"):
            two.append(files[i])
        elif(files[i].split("_")[2] == "4"):
            four.append(files[i])
        elif(files[i].split("_")[2] == "5"):
            five.append(files[i])
        elif(files[i].split("_")[2] == "6"):
            six.append(files[i])
        elif(files[i].split("_")[2] == "8"):
            eight.append(files[i])
        elif(files[i].split("_")[2] == "10"):
            ten.append(files[i])
            
#### Now all files are split into these different daily test rates.
    
    if(choice == 0):
        return np.array(zero)
    elif(choice == 1):
        return np.array(one)
    elif(choice == 2):
        return np.array(two)
    elif(choice == 4):
        return np.array(four)
    elif(choice == 5):
        return np.array(five)
    elif(choice == 6):
        return np.array(six)
    elif(choice == 8):
        return np.array(eight)
    elif(choice == 10):
        return np.array(ten)
    else:
        print("Invalid choice")

# %%
def split_test_ratio(files):
    # split by test-rates

    z = []
    p1  = []
    p2 = []
    p3  = []
    p4 = []
    p5  = []
    p6 = []
    p7 = []
    p8 = []
    p9 = []
    p10= []
    
    for i in range(0,len(files)):
        if(files[i].split("_")[5] == "0.0"):
            z.append(files[i])
        elif(files[i].split("_")[5] == "0.1"):
            p1.append(files[i])
        elif(files[i].split("_")[5] == "0.2"):
            p2.append(files[i])
        elif(files[i].split("_")[5] == "0.3"):
            p3.append(files[i])
        elif(files[i].split("_")[5] == "0.4"):
            p4.append(files[i])
        elif(files[i].split("_")[5] == "0.5"):
            p5.append(files[i])
        elif(files[i].split("_")[5] == "0.6"):
            p6.append(files[i])
        elif(files[i].split("_")[5] == "0.7"):
            p7.append(files[i])
        elif(files[i].split("_")[5] == "0.8"):
            p8.append(files[i])
        elif(files[i].split("_")[5] == "0.9"):
            p9.append(files[i])
        elif(files[i].split("_")[5] == "1.0"):
            p10.append(files[i])
            

    n_pop = 5580
    p = [z,p1,p2,p3,p4,p5,p6,p7,p8,p9,p10]
    
    data= [[],[],[],[],[],[],[],[],[],[],[]]
    
    avgs = np.zeros(len(p),float)
    stds = np.zeros(len(p),float)

    for i in range(0,len(data)):
        count = 0
        temp_av = np.zeros(120,float)
        for j in range(0, len(p[i])):
            file = np.genfromtxt(p[i][j],delimiter=" ", comments="#")
            temp_data = file[-1][4] # Get number of recovered from data
            temp_data += file[-1][2] + file[-1][3] + file[-1][5] # Adding all other infectious after 120 days
            
            all_inf = file[:,2] + file[:,3] + file[:,5]
            tx = file[:,0]
#             plt.plot(tx, all_inf/n_pop,'--',alpha=0.2,color=cools[i])
            if(len(temp_av)<len(all_inf)):
                for k in range(0,len(temp_av)):
                    temp_av[k] += all_inf[k]
            else:
                temp_av += all_inf
            count += 1
            data[i].append(temp_data)
#         tx = np.linspace(0,120,120)
#         temp_av = temp_av/(n_pop*count)
#         plt.plot(tx,temp_av,color='red',label="Daily Testing: "+str(p[0][0].split("_")[2])+"% RAT sens:"+str(p[0][0].split("_")[4])+" RAT frac:"+str(round(x_axis[i]*100))+"%")
#         plt.ylabel("Fraction of population")
#         plt.xlabel("Days")
#         plt.legend()
#         #plt.savefig("../images/Comparing_Sensitivities/Infected Graphs/"+all_files[i].split("_")[0].split("/")[-1]+"_"+"RAT_sens_"+str(all_files[i].split("_")[4])+"_frac"+str(x_axis[i]*100)+".png",facecolor='w')
#         plt.show()


    for i in range(0, len(data)):
        all_points = np.array(data[i])
        goodpoints =  all_points[np.where(all_points>0)]
        
        plt.plot(goodpoints)    
        
        avgs[i] = np.average(goodpoints)/n_pop
        stds[i] = np.std(goodpoints)/n_pop
    
    mc_count = 0
    for i in range(0,len(data)):
        all_points = np.array(data[i])
        
        goodpoints = all_points[np.where(all_points>0)]
        
        print("RAT "+str(round(i*10,2))+" has "+str(len(goodpoints)) + " MC runs")
        mc_count += len(goodpoints)
    
    plt.show()
    
    return avgs,stds,mc_count

# %%
### Printing 1% results ###

tss = [0.7,0.75,0.8,0.85,0.9,0.95]
# trs = [5]

results_1_p = np.zeros((len(tss),11))
std_ar_1_p = np.zeros((len(tss),11))


T_mc_count_1_p = 0
for i in range(0,len(tss)):
    print("Test sensitivity",tss[i])
    results_1_p[i],std_ar_1_p[i],mc_count = split_test_ratio(split_sensitivity(split_test_rate(random_txt_files,1), tss[i]))
    T_mc_count_1_p += mc_count

print(T_mc_count_1_p)
# print(results)
# print(std_ar)

res_map_1_p = plt.imshow(results_1_p,aspect="auto",extent=[0,1,75,95],origin='lower')#,interpolation="bilinear")
plt.colorbar()
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.show()

std_map_1_p = plt.imshow(std_ar_1_p,aspect="auto",extent=[0,1,0.95,75])
std_map_1_p.set_cmap("Reds_r")
plt.colorbar()
plt.show()
# Out:
# Test sensitivity 0.7
# RAT 0 has 56 MC runs
# RAT 10 has 56 MC runs
# RAT 20 has 56 MC runs
# RAT 30 has 55 MC runs
# RAT 40 has 55 MC runs
# RAT 50 has 56 MC runs
# RAT 60 has 57 MC runs
# RAT 70 has 57 MC runs
# RAT 80 has 58 MC runs
# RAT 90 has 57 MC runs
# RAT 100 has 57 MC runs
# Test sensitivity 0.75
# RAT 0 has 51 MC runs
# RAT 10 has 51 MC runs
# RAT 20 has 52 MC runs
# RAT 30 has 53 MC runs
# RAT 40 has 53 MC runs
# RAT 50 has 53 MC runs
# RAT 60 has 53 MC runs
# RAT 70 has 53 MC runs
# RAT 80 has 53 MC runs
# RAT 90 has 53 MC runs
# RAT 100 has 53 MC runs
# Test sensitivity 0.8
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.85
# RAT 0 has 48 MC runs
# RAT 10 has 48 MC runs
# RAT 20 has 48 MC runs
# RAT 30 has 49 MC runs
# RAT 40 has 49 MC runs
# RAT 50 has 49 MC runs
# RAT 60 has 49 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.9
# RAT 0 has 49 MC runs
# RAT 10 has 49 MC runs
# RAT 20 has 49 MC runs
# RAT 30 has 49 MC runs
# RAT 40 has 49 MC runs
# RAT 50 has 48 MC runs
# RAT 60 has 48 MC runs
# RAT 70 has 48 MC runs
# RAT 80 has 48 MC runs
# RAT 90 has 48 MC runs
# RAT 100 has 48 MC runs
# Test sensitivity 0.95
# RAT 0 has 52 MC runs
# RAT 10 has 51 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 49 MC runs
# RAT 50 has 49 MC runs
# RAT 60 has 49 MC runs
# RAT 70 has 49 MC runs
# RAT 80 has 49 MC runs
# RAT 90 has 49 MC runs
# RAT 100 has 49 MC runs
# 3367

# %%
### Printing for 5%

tss = [0.7,0.75,0.8,0.85,0.9,0.95]

results_5_p = np.zeros((len(tss),11))
std_ar_5_p = np.zeros((len(tss),11))


T_mc_count_5_p = 0
for i in range(0,len(tss)):
    print("Test sensitivity",tss[i])
    results_5_p[i],std_ar_5_p[i],mc_count = split_test_ratio(split_sensitivity(split_test_rate(random_txt_files,5), tss[i]))
    T_mc_count_5_p += mc_count

print(T_mc_count_5_p)
# print(results)
# print(std_ar)

res_map_5_p = plt.imshow(results_5_p,aspect="auto",extent=[0,1,75,95],origin='lower')#,interpolation="bilinear")
plt.colorbar()
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.show()

std_map_5_p = plt.imshow(std_ar_5_p,aspect="auto",extent=[0,1,0.95,75])
std_map_5_p.set_cmap("Reds_r")
plt.colorbar()

plt.show()
# Out:
# Test sensitivity 0.7
# RAT 0 has 56 MC runs
# RAT 10 has 56 MC runs
# RAT 20 has 55 MC runs
# RAT 30 has 55 MC runs
# RAT 40 has 55 MC runs
# RAT 50 has 55 MC runs
# RAT 60 has 57 MC runs
# RAT 70 has 57 MC runs
# RAT 80 has 57 MC runs
# RAT 90 has 57 MC runs
# RAT 100 has 57 MC runs
# Test sensitivity 0.75
# RAT 0 has 51 MC runs
# RAT 10 has 51 MC runs
# RAT 20 has 51 MC runs
# RAT 30 has 52 MC runs
# RAT 40 has 53 MC runs
# RAT 50 has 53 MC runs
# RAT 60 has 53 MC runs
# RAT 70 has 53 MC runs
# RAT 80 has 52 MC runs
# RAT 90 has 53 MC runs
# RAT 100 has 53 MC runs
# Test sensitivity 0.8
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.85
# RAT 0 has 48 MC runs
# RAT 10 has 48 MC runs
# RAT 20 has 48 MC runs
# RAT 30 has 49 MC runs
# RAT 40 has 49 MC runs
# RAT 50 has 49 MC runs
# RAT 60 has 49 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.9
# RAT 0 has 49 MC runs
# RAT 10 has 49 MC runs
# RAT 20 has 49 MC runs
# RAT 30 has 49 MC runs
# RAT 40 has 48 MC runs
# RAT 50 has 48 MC runs
# RAT 60 has 48 MC runs
# RAT 70 has 48 MC runs
# RAT 80 has 48 MC runs
# RAT 90 has 48 MC runs
# RAT 100 has 48 MC runs
# Test sensitivity 0.95
# RAT 0 has 52 MC runs
# RAT 10 has 51 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 49 MC runs
# RAT 50 has 49 MC runs
# RAT 60 has 49 MC runs
# RAT 70 has 49 MC runs
# RAT 80 has 49 MC runs
# RAT 90 has 49 MC runs
# RAT 100 has 49 MC runs
# 3360

# %%
### Printing fro 10%

tss = [0.7,0.75,0.8,0.85,0.9,0.95]

results_10_p = np.zeros((len(tss),11))
std_ar_10_p = np.zeros((len(tss),11))


T_mc_count_10_p = 0
for i in range(0,len(tss)):
    print("Test sensitivity",tss[i])
    results_10_p[i],std_ar_10_p[i],mc_count = split_test_ratio(split_sensitivity(split_test_rate(random_txt_files,10), tss[i]))
    T_mc_count_5_p += mc_count

print(T_mc_count_10_p)
# print(results)
# print(std_ar)

res_map_10_p = plt.imshow(results_10_p,aspect="auto",extent=[0,1,75,95],origin='lower')#,interpolation="bilinear")
plt.colorbar()
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.show()

std_map_10_p = plt.imshow(std_ar_10_p,aspect="auto",extent=[0,1,0.95,75])
std_map_10_p.set_cmap("Reds_r")
plt.colorbar()

plt.show()
# Out:
# Test sensitivity 0.7
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 49 MC runs
# RAT 80 has 49 MC runs
# RAT 90 has 49 MC runs
# RAT 100 has 49 MC runs
# Test sensitivity 0.75
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.8
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.85
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.9
# RAT 0 has 50 MC runs
# RAT 10 has 50 MC runs
# RAT 20 has 50 MC runs
# RAT 30 has 50 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 50 MC runs
# RAT 70 has 50 MC runs
# RAT 80 has 50 MC runs
# RAT 90 has 50 MC runs
# RAT 100 has 50 MC runs
# Test sensitivity 0.95
# RAT 0 has 49 MC runs
# RAT 10 has 49 MC runs
# RAT 20 has 49 MC runs
# RAT 30 has 49 MC runs
# RAT 40 has 50 MC runs
# RAT 50 has 50 MC runs
# RAT 60 has 49 MC runs
# RAT 70 has 49 MC runs
# RAT 80 has 48 MC runs
# RAT 90 has 48 MC runs
# RAT 100 has 48 MC runs
# 0

# %%
import scipy.ndimage
import matplotlib.cm as cm

plt.title("1% Testing")
res_map_1_p_inter = plt.imshow(results_1_p,aspect="auto",interpolation="bilinear",origin='lower',extent=[0,1,70,95])
plt.colorbar()
# res_map2 = plt.contour(results,20,extent=[0,1,75,95],origin = 'lower')
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.hlines(74.3,0,1,color='r')
plt.hlines(91,0,1,color='r')
plt.text(0.1,92,"Brazil  (91%)",color='black',fontsize=12)
plt.text(0.1,75,"Germany (74.3%)",color='black',fontsize=12)
# plt.clim(0,0.6)
# res_map_1_p_inter.set_cmap("Reds")

second_cmap = truncate_colormap(plt.get_cmap("Reds"),0.7,1.0)
res_map_1_p_inter.set_cmap(plt.get_cmap(second_cmap))
plt.savefig('./HM_Random_1percent.png',dpi=300,facecolor='w')
plt.show()

# smooth_data = scipy.ndimage.zoom(results,3)

# smooth_map_1_p = plt.imshow(results,aspect="auto",interpolation="bilinear",origin='lower',extent=[0,1,70,95])
# plt.colorbar()
# smooth_map2_1_p = plt.contour(smooth_data,5,extent=[0,1,70,95],origin = 'lower',cmap=cm.Greens_r)
# plt.xlabel("Fraction of RAT Tests")
# plt.ylabel("Sensitivity of RAT")

# plt.show()

plt.title("5% Testing")
res_map_5_p_inter = plt.imshow(results_5_p,aspect="auto",interpolation="bilinear",origin='lower',extent=[0,1,70,95])
plt.colorbar()
# res_map2 = plt.contour(results,20,extent=[0,1,75,95],origin = 'lower')
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.hlines(74.3,0,1,color='r')
plt.hlines(91,0,1,color='r')
plt.text(0.1,92,"Brazil  (91%)",color='black',fontsize=12)
plt.text(0.1,75,"Germany (74.3%)",color='black',fontsize=12)
# plt.clim(0,0.6)
# res_map_5_p_inter.set_cmap("plasma")
# res_map_5_p_inter.set_cmap("YlOrRd")
second_cmap = truncate_colormap(plt.get_cmap("YlOrRd"),0.2,0.8)
res_map_5_p_inter.set_cmap(plt.get_cmap(second_cmap))
plt.savefig('./HM_Random_5percent.png',dpi=300,facecolor='w')
plt.show()

plt.title("10% Testing")
res_map_10_p_inter = plt.imshow(results_10_p,aspect="auto",interpolation="bilinear",origin='lower',extent=[0,1,70,95])
plt.colorbar()
# res_map2 = plt.contour(results,20,extent=[0,1,75,95],origin = 'lower')
plt.xlabel("Fraction of RAT Tests")
plt.ylabel("Sensitivity of RAT")
plt.hlines(74.3,0,1,color='r')
plt.hlines(91,0,1,color='r')
plt.text(0.1,92,"Brazil  (91%)",color='black',fontsize=12)
plt.text(0.1,75,"Germany (74.3%)",color='black',fontsize=12)
# plt.clim(0,0.6)
# res_map_10_p_inter.set_cmap("inferno")
second_cmap = truncate_colormap(plt.get_cmap("YlOrRd"),0,0.8)
res_map_10_p_inter.set_cmap(plt.get_cmap(second_cmap))
plt.savefig('./HM_Random_10percent.png',dpi=300,facecolor='w')
plt.show()









# STD Maps
# std_map = plt.imshow(std_ar,aspect="auto",interpolation="bilinear",origin='lower',extent=[0,1,75,95],alpha=1)
# std_map.set_cmap("Reds_r")
# plt.colorbar()
# # std_map2 = plt.contour(std_ar,10,extent=[0,1,75,95],origin = 'lower')
# plt.xlabel("Fraction of RAT Tests")
# plt.ylabel("Sensitivity of RAT")

plt.show()

# %%
....
# Out:
#   File "<ipython-input-11-7834bfc346aa>", line 1
#     ....
#         ^
# SyntaxError: invalid syntax

# %%
plt.imshow(res_map_10_p, vmin=0.01, vmax=0.99)
res_map_10_p_inter.set_cmap("inferno")

# %%
# %matplotlib notebook

import numpy
import matplotlib.pyplot as plt
from matplotlib import lines
from mpl_toolkits.mplot3d import Axes3D

# Set up grid and test data
# nx, ny = 1, 3
# x = range(nx)
# y = range(ny)

x = np.linspace(0,1,11)
y = np.array([0.7,0.75,0.8,0.85,0.9,0.95])

# data = results

hf = plt.figure()
ha = hf.add_subplot(111, projection='3d')

X, Y = numpy.meshgrid(x, y)  # `plot_surface` expects `x` and `y` data to be 2D
ha.plot_surface(X, Y, results_1_p)
ha.plot_surface(X, Y, results_1_p-std_ar_1_p)
ha.plot_surface(X, Y, results_1_p+std_ar_1_p)

ha.plot_surface(X, Y, results_5_p)
ha.plot_surface(X, Y, results_10_p)

fake2Dline_1 = lines.Line2D([0],[0], linestyle="none", c='b', marker = 'o')
fake2Dline_5 = lines.Line2D([0],[0], linestyle="none", c='darkorange', marker = 'o')
fake2Dline_10 = lines.Line2D([0],[0], linestyle="none", c='g', marker = 'o')

# ha.contour3D(X,Y,data,200)

plt.locator_params(axis = 'y', nbins = 1)
plt.locator_params(axis = 'x', nbins = 3)


plt.ylabel("RAT Sensitivity")
plt.xlabel("Fraction of RATs")
plt.legend([fake2Dline_1,fake2Dline_5,fake2Dline_10],["1% testing","5% testing","10% testing"],numpoints=1)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for i in np.linspace(0,1,11):
    print(i)

# %%
# def plot_graph(all_files,cc):
# #     print(all_files[0])
#     if cc[0] == 0:
#         if(cc[2] == 0):
#             clrs = plt.cm.Blues(np.linspace(0.5,1,6))
#         elif(cc[2] == 1):
#             clrs = plt.cm.Greens(np.linspace(0.5,1,6))
#     elif cc[0] == 1:
#         if(cc[2] == 0):
#             clrs = plt.cm.Reds(np.linspace(0.5,1,6))
#         elif(cc[2] == 1):
#             clrs = plt.cm.Oranges(np.linspace(0.5,1,6))
    
    
#     p_0_0 = []
#     p_0_2 = []
#     p_0_4 = []
#     p_0_6 = []
#     p_0_8 = []
#     p_0_9 = []
#     p_1_0 = []

#     p = [p_0_0, p_0_2, p_0_4, p_0_6, p_0_8, p_0_9, p_1_0]
#     x_axis = np.array([0.0, 0.2, 0.4, 0.6, 0.8, 0.9, 1.0])
    
#     for i in range(0,len(all_files)):
#         if(all_files[i].split("_")[5]=="0.0"):
#             p_0_0.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="0.2"):
#             p_0_2.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="0.4"):
#             p_0_4.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="0.6"):
#             p_0_6.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="0.8"):
#             p_0_8.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="0.9"):
#             p_0_9.append(all_files[i])
#         elif(all_files[i].split("_")[5]=="1.0"):
#             p_1_0.append(all_files[i])

    
#     data = [[],[],[],[],[],[],[]]
    
#     cools = ['blue','green','magenta','orange','orangered','maroon','red']

#     n_pop = 10000
    
#     print("*** Data ***")
    
#     for i in range(0,len(data)):
#         count = 0
#         temp_av = np.zeros(120,float)
#         for j in range(0, len(p[i])):
#             temp_data = np.genfromtxt(p[i][j],delimiter=" ", comments="#")[-1][4] # Get number of recovered from data
#             temp_data += np.genfromtxt(p[i][j],delimiter=" ", comments="#")[-1][2]+np.genfromtxt(p[i][j],delimiter=" ", comments="#")[-1][3]+np.genfromtxt(p[i][j],delimiter=" ", comments="#")[-1][5] # DOING THIS BECAUSE I ONLY PLOTTED TILL 100 days, but infection completely dies out later
            
#             all_inf = np.genfromtxt(p[i][j],delimiter=" ", comments="#")[:,2]+np.genfromtxt(p[i][j],delimiter=" ", comments="#")[:,3]+np.genfromtxt(p[i][j],delimiter=" ", comments="#")[:,5]
#             tx = np.genfromtxt(p[i][j],delimiter=" ", comments="#")[:,0]
# #             plt.plot(tx, all_inf/n_pop,'--',alpha=0.2,color=cools[i])
#             if(len(temp_av)<len(all_inf)):
#                 for k in range(0,len(temp_av)):
#                     temp_av[k] += all_inf[k]
#             else:
#                 temp_av += all_inf
#             count += 1
#             data[i].append(temp_data)
#         print("RAT "+str(x_axis[i]*100)+"% "+str(data[i])+" "+ str(len(data[i]))+" runs")
# #         plt.yscale('log')
#         print(count)
# #         tx = np.linspace(0,120,120)
# #         temp_av = temp_av/(n_pop*count)
# #         plt.plot(tx,temp_av,color='red',label="Daily Testing: "+str(all_files[0].split("_")[2])+"% RAT sens:"+str(all_files[0].split("_")[4])+" RAT frac:"+str(round(x_axis[i]*100))+"%")
# #         plt.ylabel("Fraction of population")
# #         plt.xlabel("Days")
# #         plt.legend()
# #         plt.savefig("../images/Comparing_Sensitivities/Infected Graphs/"+all_files[i].split("_")[0].split("/")[-1]+"_"+"RAT_sens_"+str(all_files[i].split("_")[4])+"_frac"+str(x_axis[i]*100)+".png",facecolor='w')
# #         plt.show()


#     avgs = np.zeros(len(p),float)
#     stds = np.zeros(len(p),float)

    

#     for i in range(0,len(avgs)):
#         if(len(data[i])>0):
#             avgs[i] = np.average(data[i])/n_pop
#             stds[i] = np.std(data[i])/n_pop
#         else:
#             avgs[i] = np.nan
#             stds[i] = np.nan
    
#     if(len(all_files)!=0):
#         plt.title(all_files[0].split("_")[0].split("/")[-1]+" "+all_files[0].split("_")[1]+": RAT Sensitivity - "+all_files[0].split("_")[4])
    
#         plt.xlabel("Percentage of total tests that are RAT (%)")
#         plt.ylabel("Asymptotic Fraction Infected")
#         #plt.locator_params(nbins = len(labels),axis='x')
#     #     plt.xticks(fontsize=20)
#     #     plt.yticks(fontsize=20)

#     #     plt.plot(x_axis*100, avgs,'-o',color=clrs[0],label=all_files[0].split("_")[2]+"% "+ all_files[i].split("_")[0].split("/")[-1]+" Testing Daily")
#         plt.plot(x_axis*100, avgs,'-o',color=clrs[cc[1]],label=all_files[0].split("_")[2]+"% Testing Daily",alpha=1)#0.7*cc[1])
#         plt.errorbar(x_axis*100,avgs,yerr=stds,ls='none',color=clrs[cc[1]],solid_capstyle='projecting', capsize=5,alpha=0.5)
#     #     plt.legend()
#     #     plt.savefig("../images/Comparing_Sensitivities/"+all_files[i].split("_")[0].split("/")[-1]+"_"+all_files[i].split("_")[1]+all_files[i].split("_")[2]+"_BETA06_.png",dpi=500,facecolor='w')
#     #     plt.show()

# %%
# plot_graph(random_txt_files,['dodgerblue','tomato'])
# plot_graph(targetted_txt_files,['lightseagreen','tomato'])

# %%
# tss = [0.6,0.8]
# trs = [2,4,6,8]

# for i in range(0,len(tss)):
#     for j in range(0,len(trs)):
#         plot_graph(split_test_rate(split_sensitivity(targetted_txt_files,tss[i]),trs[j]),[i,j,1])
#     plt.legend()
# #     plt.savefig("../images/Comparing_Sensitivities/New_Increased_AFraction/Targetted_Testing_Sensitivity_"+str(tss[i])+".png",facecolor='w',dpi=500)
#     plt.show()

# %%
# tss = [0.6, 0.8]
# trs = [0,2,4,6,8]

# for i in range(0,len(tss)):
#     for j in range(0,len(trs)):
#         plot_graph(split_test_rate(split_sensitivity(random_txt_files,tss[i]),trs[j]),[i,j,0])
#     plt.legend()
# #     plt.savefig("../images/Comparing_Sensitivities/New_Increased_AFraction/Random_Testing_Sensitivity_"+str(tss[i])+".png",facecolor='w',dpi=500)
#     plt.show()

# %%
def js(files,choice):
    # split by test-rates

    z = []
    p1  = []
    p2 = []
    p3  = []
    p4 = []
    p5  = []
    p6 = []
    p7 = []
    p8 = []
    p9 = []
    p10= []
    
    for i in range(0,len(files)):
        if(files[i].split("_")[5] == "0.0"):
            z.append(files[i])
        elif(files[i].split("_")[5] == "0.1"):
            p1.append(files[i])
        elif(files[i].split("_")[5] == "0.2"):
            p2.append(files[i])
        elif(files[i].split("_")[5] == "0.3"):
            p3.append(files[i])
        elif(files[i].split("_")[5] == "0.4"):
            p4.append(files[i])
        elif(files[i].split("_")[5] == "0.5"):
            p5.append(files[i])
        elif(files[i].split("_")[5] == "0.6"):
            p6.append(files[i])
        elif(files[i].split("_")[5] == "0.7"):
            p7.append(files[i])
        elif(files[i].split("_")[5] == "0.8"):
            p8.append(files[i])
        elif(files[i].split("_")[5] == "0.9"):
            p9.append(files[i])
        elif(files[i].split("_")[5] == "1.0"):
            p10.append(files[i])
            

    n_pop = 5580
   
    if(choice==0):
        return 0
    elif(choice==0.1):
        return p1
    elif(choice==0.2):
        return p2
    elif(choice==0.3):
        return p3
    elif(choice==0.4):
        return p4
    elif(choice==0.5):
        return p5
    elif(choice==0.6):
        return p6
    elif(choice==0.7):
        return p7
    elif(choice==0.8):
        return p8
    elif(choice==0.9):
        return p9
    elif(choice==1):
        return p10

# %%
r = js(split_sensitivity(split_test_rate(random_txt_files,5), 0.75),0.9)

# %%
inf = []
hos = []
for i in range(0,len(r)):
    
    file = np.genfromtxt(r[i],delimiter=" ", comments="#")
    inf.append(file[:,2]+file[:,3]+file[:,5])
    hos.append(file[:,5])

inf = np.array(inf)
hos = np.array(hos)

# %%
inf_av = np.zeros(121)

plt.title("Infected (5% testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),inf[i]/10000,'--',color='darkgoldenrod',alpha=0.2)
    inf_av = inf_av + inf[i]
inf_av = inf_av/len(inf)/10000
plt.plot(np.linspace(0,120,121),inf_av,'orange')
plt.ylabel("Fraction of population infected")
plt.xlabel("Time (Days)")
plt.savefig("./rand_fraction_infected_5percent.png",dpi=100,facecolor='w')
plt.show()

hos_av = np.zeros(121)
plt.title("Hospitalised (5% testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),hos[i]/10000,'--',color='green',alpha=0.2)
    hos_av = hos_av + hos[i]
hos_av = hos_av/len(hos)/10000
plt.plot(np.linspace(0,120,121),hos_av,'darkgreen')
plt.ylabel("Fraction of population hospitalised")
plt.xlabel("Time (Days)")
plt.savefig("./rand_fraction_hospitalised_5percent.png",dpi=100,facecolor='w')
plt.show()

# %%
r = js(split_sensitivity(split_test_rate(random_txt_files,1), 0.75),0.9)

# %%
inf = []
hos = []
for i in range(0,len(r)):
    
    file = np.genfromtxt(r[i],delimiter=" ", comments="#")
    inf.append(file[:,2]+file[:,3]+file[:,5])
    hos.append(file[:,5])

inf = np.array(inf)
hos = np.array(hos)

# %%
inf_av = np.zeros(121)

plt.title("Infected (1% testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),inf[i]/10000,'--',color='indianred',alpha=0.2)
    inf_av = inf_av + inf[i]
inf_av = inf_av/len(inf)/10000
plt.plot(np.linspace(0,120,121),inf_av,'r')
plt.ylabel("Fraction of population infected")
plt.xlabel("Time (Days)")
plt.savefig("./rand_fraction_infected_1percent.png",dpi=100,facecolor='w')
plt.show()

hos_av = np.zeros(121)
plt.title("Hospitalised (1% testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),hos[i]/10000,'--',color='teal',alpha=0.2)
    hos_av = hos_av + hos[i]
hos_av = hos_av/len(hos)/10000
plt.plot(np.linspace(0,120,121),hos_av,'navy')
plt.ylabel("Fraction of population hospitalised")
plt.xlabel("Time (Days)")
plt.savefig("./rand_fraction_hospitalised_1percent.png",dpi=100,facecolor='w')
plt.show()

# %%
r = js(split_sensitivity(split_test_rate(random_txt_files,0), 0.75),1.0)
inf = []
hos = []
print(len(r))
for i in range(0,len(r)):
    
    file = np.genfromtxt(r[i],delimiter=" ", comments="#")
    inf.append(file[:,2]+file[:,3]+file[:,5])
    hos.append(file[:,5])

inf = np.array(inf)
hos = np.array(hos)

inf_av = np.zeros(121)

plt.title("Infected (No testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),inf[i]/10000,'--',color='firebrick',alpha=0.2)
    inf_av = inf_av + inf[i]
inf_av = inf_av/len(inf)/10000
plt.plot(np.linspace(0,120,121),inf_av,'r')
plt.ylabel("Fraction of population infected")
plt.xlabel("Time (Days)")
plt.savefig("./fraction_infected_notesting.png",dpi=100,facecolor='w')
plt.show()

hos_av = np.zeros(121)
plt.title("Hospitalised (No testing)")
for i in range(0,len(inf)):
    plt.plot(np.linspace(0,120,121),hos[i]/10000,'--',color='royalblue',alpha=0.2)
    hos_av = hos_av + hos[i]
hos_av = hos_av/len(hos)/10000
plt.plot(np.linspace(0,120,121),hos_av,'navy')
plt.ylabel("Fraction of population hospitalised")
plt.xlabel("Time (Days)")
plt.savefig("./fraction_hospitalised_notesting.png",dpi=100,facecolor='w')
plt.show()
# Out:
# 42

# %%
print(np.array(r))
# Out:
# ['../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145746182640.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150813227663.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150038387041.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150933712538.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150936219808.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145617434604.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145952174163.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145830283277.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145701795316.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150935132160.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145621430737.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145654172662.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145828644687.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150810209776.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145915277947.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145953869785.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004151018737782.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145907673422.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150809005976.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150135733012.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150047930345.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145535131472.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150213989869.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145541192010.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145738503298.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150854437474.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150038442190.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145529800725.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145611098614.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150852173178.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145703524611.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150219182498.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145959973169.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150128868686.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150127084437.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004151020053220.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145822996455.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150211329182.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004151020047612.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145745824384.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004150850999333.txt'
#  '../data/RandomTesting/Random_Testing_0_RAT_0.75_1.0_PCR_1.0_0.0_201004145911544554.txt']
